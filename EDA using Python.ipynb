# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/sushm/OneDrive/Desktop/DataScience/drug.csv")

# %%
data.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
data.tail()
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX

# %%
data.shape
# Out:
# (200, 6)

# %%
data.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
data.nunique()
# Out:
# Age             57
# Sex              2
# BP               3
# Cholesterol      2
# Na_to_K        198
# Drug             5
# dtype: int64

# %%
data['Sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
#Cleaning

# %%
data.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
drug.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17956\2719128074.py in <module>
# ----> 1 drug.head()
#
# NameError: name 'drug' is not defined

# %%
drug = data.drop(['BP'],axis=1)

# %%
drug.head()
# Out:
#    Age Sex Cholesterol  Na_to_K   Drug
# 0   23   F        HIGH   25.355  DrugY
# 1   47   M        HIGH   13.093  drugC
# 2   47   M        HIGH   10.114  drugC
# 3   28   F        HIGH    7.798  drugX
# 4   61   F        HIGH   18.043  DrugY

# %%
corelation = drug.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(drug)

# %%
sns.relplot(x='Age',y='Na_to_K',hue='Drug',data=drug)

# %%
sns.distplot(drug['Na_to_K'],bins=5)
# Out:
# <AxesSubplot:xlabel='Na_to_K', ylabel='Density'>

# %%
sns.catplot(x='Na_to_K',kind='box',data=drug)
